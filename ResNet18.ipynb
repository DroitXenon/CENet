# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
import torch.backends.mps as mps 
import copy
import time
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %% [markdown]
# # Configuration

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running on device: {device}")
# Out:
# Running on device: cuda

# %% [markdown]
# # Load Datasets

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

batch_size = 64
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# %% [markdown]
# # LeNet

# %%
def resnet18():
    model = models.resnet18(weights=None)  # Use pretrained=True if desired
    model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    model.maxpool = nn.Identity()
    model.fc = nn.Linear(512, 10)  # CIFAR-10 has 10 classes
    return model

# %% [markdown]
# # Evaluate

# %%
def evaluate_model(model, dataloader):
    correct, total = 0, 0
    model.eval()
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total  # Accuracy in %

# %%
def compute_communication_efficiency(final_accuracy, sync_steps):
    return final_accuracy / sync_steps if sync_steps > 0 else final_accuracy

# %%
def measure_communication_cost(model, compression_factor=1.0):
    total_size = 0
    for param in model.parameters():
        if param.grad is not None:
            param_size = param.grad.numel() * param.grad.element_size()  # Size in bytes
            total_size += param_size * compression_factor
    return total_size / (1024 * 1024)  # Convert to MB

# %% [markdown]
# # AGC Function

# %%
def apply_agc_quantization(model, num_bits=8):
    scale = 2 ** num_bits - 1
    for param in model.parameters():
        if param.grad is not None:
            grad = param.grad
            min_val, max_val = grad.min(), grad.max()
            grad = (grad - min_val) / (max_val - min_val) * scale
            grad = torch.round(grad) / scale * (max_val - min_val) + min_val
            param.grad = grad

# %% [markdown]
# # Training function

# %%
def train_baseline(model, epochs=10):
    model = copy.deepcopy(model).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_history = []
    accuracy_history = []
    communication_cost_history = []
    
    for epoch in range(epochs):
        running_loss = 0.0
        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        avg_loss = running_loss / len(trainloader)
        loss_history.append(avg_loss)
        accuracy_history.append(evaluate_model(model, testloader))
        communication_cost = measure_communication_cost(model)
        communication_cost_history.append(communication_cost)
        print("Epoch %d: Loss = %.4f, Accuracy = %.2f%%, Communication Cost: %.4f MB" % (epoch + 1, avg_loss, accuracy_history[-1], communication_cost))
    
    return model, loss_history, accuracy_history, communication_cost_history

# %%
def train_with_agc(model, epochs=10):
    model = copy.deepcopy(model).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_history = []
    accuracy_history = []
    communication_cost_history = []

    
    for epoch in range(epochs):
        running_loss = 0.0
        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            apply_agc_quantization(model)  # Apply AGC using quantization
            optimizer.step()
            running_loss += loss.item()
        
        avg_loss = running_loss / len(trainloader)
        loss_history.append(avg_loss)
        accuracy_history.append(evaluate_model(model, testloader))
        communication_cost = measure_communication_cost(model, compression_factor=0.125)  # 8x compression
        communication_cost_history.append(communication_cost)
        print("Epoch %d: Loss = %.4f, Accuracy = %.2f%%, Communication Cost: %.4f MB" % (epoch + 1, avg_loss, accuracy_history[-1], communication_cost))
    
    return model, loss_history, accuracy_history, communication_cost_history

# %%
def train_with_lusgd(model, K=5, epochs=10):
    model = copy.deepcopy(model).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_history = []
    accuracy_history = []
    communication_cost_history = []

    
    for epoch in range(epochs):
        running_loss = 0.0
        local_model = copy.deepcopy(model.state_dict())

        for i, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            
            if (i + 1) % K == 0:
                with torch.no_grad():
                    global_state_dict = model.state_dict()
                    for key in global_state_dict:
                        global_state_dict[key] = (global_state_dict[key] + local_model[key]) / 2
                    model.load_state_dict(global_state_dict)
                local_model = copy.deepcopy(model.state_dict())
        
        avg_loss = running_loss / len(trainloader)
        loss_history.append(avg_loss)
        accuracy_history.append(evaluate_model(model, testloader))
        communication_cost = measure_communication_cost(model)
        communication_cost_history.append(communication_cost)
        print("Epoch %d: Loss = %.4f, Accuracy = %.2f%%, Communication Cost: %.4f MB" % (epoch + 1, avg_loss, accuracy_history[-1], communication_cost))
    
    return model, loss_history, accuracy_history, communication_cost_history

# %%
def train_hybrid(model, K=5, epochs=10, compression_factor=0.125):
    model = copy.deepcopy(model).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_history = []
    accuracy_history = []
    communication_cost_history = []

    for epoch in range(epochs):
        running_loss = 0.0
        local_model = copy.deepcopy(model.state_dict())

        for i, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            apply_agc_quantization(model)
            optimizer.step()
            running_loss += loss.item()

            if (i + 1) % K == 0:
                with torch.no_grad():
                    global_state_dict = model.state_dict()
                    for key in global_state_dict:
                        global_state_dict[key] = (global_state_dict[key] + local_model[key]) / 2
                    model.load_state_dict(global_state_dict)
                local_model = copy.deepcopy(model.state_dict())

        avg_loss = running_loss / len(trainloader)
        loss_history.append(avg_loss)
        accuracy_history.append(evaluate_model(model, testloader))
        communication_cost = measure_communication_cost(model, compression_factor=compression_factor)
        communication_cost_history.append(communication_cost)

        print("Epoch %d: Loss = %.4f, Accuracy = %.2f%%, Communication Cost: %.4f MB" %
              (epoch + 1, avg_loss, accuracy_history[-1], communication_cost))

    return model, loss_history, accuracy_history, communication_cost_history

# %% [markdown]
# # Train Model

# %%
print("Training Baseline Model")
baseline_model, baseline_loss, baseline_acc, baseline_cost = train_baseline(resnet18(), epochs=50)
baseline_efficiency = compute_communication_efficiency(baseline_acc[-1], len(trainloader))
# Out:
# Training Baseline Model
# Epoch 1: Loss = 1.1870, Accuracy = 60.57%, Communication Cost: 42.6253 MB
# Epoch 2: Loss = 1.8209, Accuracy = 48.12%, Communication Cost: 42.6253 MB
# Epoch 3: Loss = 1.1688, Accuracy = 67.34%, Communication Cost: 42.6253 MB
# Epoch 4: Loss = 0.8375, Accuracy = 72.54%, Communication Cost: 42.6253 MB
# Epoch 5: Loss = 0.6408, Accuracy = 77.20%, Communication Cost: 42.6253 MB
# Epoch 6: Loss = 0.5002, Accuracy = 80.43%, Communication Cost: 42.6253 MB
# Epoch 7: Loss = 0.3713, Accuracy = 81.22%, Communication Cost: 42.6253 MB
# Epoch 8: Loss = 0.2495, Accuracy = 81.90%, Communication Cost: 42.6253 MB
# Epoch 9: Loss = 0.1687, Accuracy = 80.92%, Communication Cost: 42.6253 MB
# Epoch 10: Loss = 0.1108, Accuracy = 80.94%, Communication Cost: 42.6253 MB
# Epoch 11: Loss = 0.0895, Accuracy = 80.58%, Communication Cost: 42.6253 MB
# Epoch 12: Loss = 0.0698, Accuracy = 81.37%, Communication Cost: 42.6253 MB
# Epoch 13: Loss = 0.0616, Accuracy = 80.73%, Communication Cost: 42.6253 MB
# Epoch 14: Loss = 0.0578, Accuracy = 81.14%, Communication Cost: 42.6253 MB
# Epoch 15: Loss = 0.0573, Accuracy = 81.89%, Communication Cost: 42.6253 MB
# Epoch 16: Loss = 0.0483, Accuracy = 80.92%, Communication Cost: 42.6253 MB
# Epoch 17: Loss = 0.0441, Accuracy = 80.29%, Communication Cost: 42.6253 MB
# Epoch 18: Loss = 0.0426, Accuracy = 81.89%, Communication Cost: 42.6253 MB
# Epoch 19: Loss = 0.0388, Accuracy = 80.65%, Communication Cost: 42.6253 MB
# Epoch 20: Loss = 0.0383, Accuracy = 81.44%, Communication Cost: 42.6253 MB
# Epoch 21: Loss = 0.0367, Accuracy = 80.09%, Communication Cost: 42.6253 MB
# Epoch 22: Loss = 0.0380, Accuracy = 80.78%, Communication Cost: 42.6253 MB
# Epoch 23: Loss = 0.0347, Accuracy = 80.76%, Communication Cost: 42.6253 MB
# Epoch 24: Loss = 0.0332, Accuracy = 79.78%, Communication Cost: 42.6253 MB
# Epoch 25: Loss = 0.0317, Accuracy = 81.83%, Communication Cost: 42.6253 MB
# Epoch 26: Loss = 0.0325, Accuracy = 80.86%, Communication Cost: 42.6253 MB
# Epoch 27: Loss = 0.0289, Accuracy = 81.58%, Communication Cost: 42.6253 MB
# Epoch 28: Loss = 0.0303, Accuracy = 81.72%, Communication Cost: 42.6253 MB
# Epoch 29: Loss = 0.0267, Accuracy = 81.23%, Communication Cost: 42.6253 MB
# Epoch 30: Loss = 0.0282, Accuracy = 80.79%, Communication Cost: 42.6253 MB
# Epoch 31: Loss = 0.0244, Accuracy = 80.82%, Communication Cost: 42.6253 MB
# Epoch 32: Loss = 0.0259, Accuracy = 81.07%, Communication Cost: 42.6253 MB
# Epoch 33: Loss = 0.0247, Accuracy = 81.04%, Communication Cost: 42.6253 MB
# Epoch 34: Loss = 0.0310, Accuracy = 80.70%, Communication Cost: 42.6253 MB

# %%
print("Training Model with AGC")
agc_model, agc_loss, agc_acc, agc_cost = train_with_agc(resnet18(), epochs=50)
agc_efficiency = compute_communication_efficiency(agc_acc[-1], len(trainloader))
# Out:
# Training Model with AGC
# Epoch 1: Loss = 1.1983, Accuracy = 65.22%, Communication Cost: 5.3282 MB
# Epoch 2: Loss = 0.9515, Accuracy = 73.46%, Communication Cost: 5.3282 MB
# Epoch 3: Loss = 0.6337, Accuracy = 77.24%, Communication Cost: 5.3282 MB
# Epoch 4: Loss = 0.4887, Accuracy = 79.32%, Communication Cost: 5.3282 MB
# Epoch 5: Loss = 0.3579, Accuracy = 81.57%, Communication Cost: 5.3282 MB
# Epoch 6: Loss = 0.2532, Accuracy = 82.48%, Communication Cost: 5.3282 MB
# Epoch 7: Loss = 0.1641, Accuracy = 81.62%, Communication Cost: 5.3282 MB
# Epoch 8: Loss = 0.1211, Accuracy = 81.18%, Communication Cost: 5.3282 MB
# Epoch 9: Loss = 0.0912, Accuracy = 80.17%, Communication Cost: 5.3282 MB
# Epoch 10: Loss = 0.0743, Accuracy = 81.17%, Communication Cost: 5.3282 MB
# Epoch 11: Loss = 0.0716, Accuracy = 80.06%, Communication Cost: 5.3282 MB
# Epoch 12: Loss = 0.0582, Accuracy = 81.90%, Communication Cost: 5.3282 MB
# Epoch 13: Loss = 0.0541, Accuracy = 82.09%, Communication Cost: 5.3282 MB
# Epoch 14: Loss = 0.0506, Accuracy = 81.83%, Communication Cost: 5.3282 MB
# Epoch 15: Loss = 0.0465, Accuracy = 82.30%, Communication Cost: 5.3282 MB
# Epoch 16: Loss = 0.0484, Accuracy = 82.41%, Communication Cost: 5.3282 MB
# Epoch 17: Loss = 0.0363, Accuracy = 81.23%, Communication Cost: 5.3282 MB
# Epoch 18: Loss = 0.0432, Accuracy = 81.20%, Communication Cost: 5.3282 MB
# Epoch 19: Loss = 0.0390, Accuracy = 81.96%, Communication Cost: 5.3282 MB
# Epoch 20: Loss = 0.0311, Accuracy = 81.62%, Communication Cost: 5.3282 MB
# Epoch 21: Loss = 0.0353, Accuracy = 82.23%, Communication Cost: 5.3282 MB
# Epoch 22: Loss = 0.0331, Accuracy = 81.81%, Communication Cost: 5.3282 MB
# Epoch 23: Loss = 0.0364, Accuracy = 81.12%, Communication Cost: 5.3282 MB
# Epoch 24: Loss = 0.0301, Accuracy = 81.35%, Communication Cost: 5.3282 MB
# Epoch 25: Loss = 0.0257, Accuracy = 82.40%, Communication Cost: 5.3282 MB
# Epoch 26: Loss = 0.0255, Accuracy = 82.36%, Communication Cost: 5.3282 MB
# Epoch 27: Loss = 0.0323, Accuracy = 82.49%, Communication Cost: 5.3282 MB
# Epoch 28: Loss = 0.0266, Accuracy = 82.16%, Communication Cost: 5.3282 MB
# Epoch 29: Loss = 0.0242, Accuracy = 80.80%, Communication Cost: 5.3282 MB
# Epoch 30: Loss = 0.0288, Accuracy = 82.43%, Communication Cost: 5.3282 MB

# %%
print("Training Model with LU-SGD")
lusgd_model, lusgd_loss, lusgd_acc, lusgd_cost = train_with_lusgd(resnet18(), epochs=50)
lusgd_efficiency = compute_communication_efficiency(lusgd_acc[-1], len(trainloader) // 5)  # LU-SGD syncs every K=5 steps
# Out:
# Training Model with LU-SGD
# Epoch 1: Loss = 1.1488, Accuracy = 63.55%, Communication Cost: 42.6253 MB
# Epoch 2: Loss = 1.7087, Accuracy = 51.84%, Communication Cost: 42.6253 MB
# Epoch 3: Loss = 1.0783, Accuracy = 66.90%, Communication Cost: 42.6253 MB
# Epoch 4: Loss = 0.8143, Accuracy = 65.29%, Communication Cost: 42.6253 MB
# Epoch 5: Loss = 0.6369, Accuracy = 74.38%, Communication Cost: 42.6253 MB
# Epoch 6: Loss = 0.4798, Accuracy = 78.53%, Communication Cost: 42.6253 MB
# Epoch 7: Loss = 0.3396, Accuracy = 77.89%, Communication Cost: 42.6253 MB
# Epoch 8: Loss = 0.2123, Accuracy = 78.52%, Communication Cost: 42.6253 MB
# Epoch 9: Loss = 0.1352, Accuracy = 78.80%, Communication Cost: 42.6253 MB
# Epoch 10: Loss = 0.0924, Accuracy = 78.68%, Communication Cost: 42.6253 MB
# Epoch 11: Loss = 0.0727, Accuracy = 78.49%, Communication Cost: 42.6253 MB
# Epoch 12: Loss = 0.0650, Accuracy = 79.37%, Communication Cost: 42.6253 MB
# Epoch 13: Loss = 0.0573, Accuracy = 78.80%, Communication Cost: 42.6253 MB
# Epoch 14: Loss = 0.0538, Accuracy = 78.99%, Communication Cost: 42.6253 MB
# Epoch 15: Loss = 0.0470, Accuracy = 79.90%, Communication Cost: 42.6253 MB
# Epoch 16: Loss = 0.0424, Accuracy = 78.98%, Communication Cost: 42.6253 MB
# Epoch 17: Loss = 0.0401, Accuracy = 78.78%, Communication Cost: 42.6253 MB
# Epoch 18: Loss = 0.0406, Accuracy = 79.21%, Communication Cost: 42.6253 MB
# Epoch 19: Loss = 0.0424, Accuracy = 79.32%, Communication Cost: 42.6253 MB
# Epoch 20: Loss = 0.0346, Accuracy = 79.38%, Communication Cost: 42.6253 MB
# Epoch 21: Loss = 0.0342, Accuracy = 78.03%, Communication Cost: 42.6253 MB

# %%
print("Training Model with Hybrid AGC + LU-SGD")
hybrid_model, hybrid_loss, hybrid_acc, hybrid_cost = train_hybrid(resnet18(), epochs=50)
hybrid_efficiency = compute_communication_efficiency(hybrid_acc[-1], len(trainloader) // 5)
# Out:
# Training Model with Hybrid AGC + LU-SGD
# Epoch 1: Loss = 1.1566, Accuracy = 65.28%, Communication Cost: 5.3282 MB
# Epoch 2: Loss = 1.8047, Accuracy = 46.07%, Communication Cost: 5.3282 MB
# Epoch 3: Loss = 1.1719, Accuracy = 63.53%, Communication Cost: 5.3282 MB
# Epoch 4: Loss = 0.8842, Accuracy = 67.25%, Communication Cost: 5.3282 MB
# Epoch 5: Loss = 0.6840, Accuracy = 74.28%, Communication Cost: 5.3282 MB

# %% [markdown]
# # Result

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(len(baseline_loss)), baseline_loss, label="Baseline", marker='o')
plt.plot(range(len(agc_loss)), agc_loss, label="AGC", marker='s')
plt.plot(range(len(lusgd_loss)), lusgd_loss, label="LU-SGD", marker='^')
plt.plot(range(len(hybrid_loss)), hybrid_loss, label="Hybrid AGC + LU-SGD", marker='x')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Convergence Speed Over Time (Loss vs. Epochs)")
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(10, 6))
#       2 plt.plot(range(len(baseline_loss)), baseline_loss, label="Baseline", marker='o')
#       3 plt.plot(range(len(agc_loss)), agc_loss, label="AGC", marker='s')
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(len(baseline_acc)), baseline_acc, label="Baseline", marker='o')
plt.plot(range(len(agc_acc)), agc_acc, label="AGC", marker='s')
plt.plot(range(len(lusgd_acc)), lusgd_acc, label="LU-SGD", marker='^')
plt.plot(range(len(hybrid_acc)), hybrid_acc, label="Hybrid AGC + LU-SGD", marker='x')
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy Comparison Over Time")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(["Baseline", "AGC", "LU-SGD", "Hybrid"], [baseline_efficiency, agc_efficiency, lusgd_efficiency, hybrid_efficiency])
plt.xlabel("Algorithm")
plt.ylabel("Communication Efficiency")
plt.title("Communication Efficiency Comparison")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(["Baseline", "AGC", "LU-SGD", "Hybrid"], [baseline_cost[0], agc_cost[0], lusgd_cost[0], hybrid_cost[0]])
plt.xlabel("Algorithm")
plt.ylabel("Gradient Size (MB)")
plt.title("Gradient Size Comparison")
plt.grid()
plt.show()
