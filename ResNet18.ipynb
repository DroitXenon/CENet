# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
import torch.backends.mps as mps 
import copy
import time
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %% [markdown]
# # Configuration

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running on device: {device}")
# Out:
# Running on device: cuda

# %% [markdown]
# # Load Datasets

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

batch_size = 64
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# %% [markdown]
# # LeNet

# %%
def resnet18():
    model = models.resnet18(weights=None)  # Use pretrained=True if desired
    model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    model.maxpool = nn.Identity()
    model.fc = nn.Linear(512, 10)  # CIFAR-10 has 10 classes
    return model

# %% [markdown]
# # Evaluate

# %%
def evaluate_model(model, dataloader):
    correct, total = 0, 0
    model.eval()
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total  # Accuracy in %

# %%
def compute_communication_efficiency(final_accuracy, sync_steps):
    return final_accuracy / sync_steps if sync_steps > 0 else final_accuracy

# %%
def measure_communication_cost(model, compression_factor=1.0):
    total_size = 0
    for param in model.parameters():
        if param.grad is not None:
            param_size = param.grad.numel() * param.grad.element_size()  # Size in bytes
            total_size += param_size * compression_factor
    return total_size / (1024 * 1024)  # Convert to MB

# %% [markdown]
# # AGC Function

# %%
def apply_agc_quantization(model, num_bits=8):
    scale = 2 ** num_bits - 1
    for param in model.parameters():
        if param.grad is not None:
            grad = param.grad
            min_val, max_val = grad.min(), grad.max()
            grad = (grad - min_val) / (max_val - min_val) * scale
            grad = torch.round(grad) / scale * (max_val - min_val) + min_val
            param.grad = grad

# %% [markdown]
# # Training function

# %%
def train_baseline(model, epochs=10):
    model = copy.deepcopy(model).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_history = []
    accuracy_history = []
    communication_cost_history = []
    
    for epoch in range(epochs):
        running_loss = 0.0
        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        avg_loss = running_loss / len(trainloader)
        loss_history.append(avg_loss)
        accuracy_history.append(evaluate_model(model, testloader))
        communication_cost = measure_communication_cost(model)
        communication_cost_history.append(communication_cost)
        print("Epoch %d: Loss = %.4f, Accuracy = %.2f%%, Communication Cost: %.4f MB" % (epoch + 1, avg_loss, accuracy_history[-1], communication_cost))
    
    return model, loss_history, accuracy_history, communication_cost_history

# %%
def train_with_agc(model, epochs=10):
    model = copy.deepcopy(model).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_history = []
    accuracy_history = []
    communication_cost_history = []

    
    for epoch in range(epochs):
        running_loss = 0.0
        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            apply_agc_quantization(model)  # Apply AGC using quantization
            optimizer.step()
            running_loss += loss.item()
        
        avg_loss = running_loss / len(trainloader)
        loss_history.append(avg_loss)
        accuracy_history.append(evaluate_model(model, testloader))
        communication_cost = measure_communication_cost(model, compression_factor=0.125)  # 8x compression
        communication_cost_history.append(communication_cost)
        print("Epoch %d: Loss = %.4f, Accuracy = %.2f%%, Communication Cost: %.4f MB" % (epoch + 1, avg_loss, accuracy_history[-1], communication_cost))
    
    return model, loss_history, accuracy_history, communication_cost_history

# %%
def train_with_lusgd(model, K=5, epochs=10):
    model = copy.deepcopy(model).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_history = []
    accuracy_history = []
    communication_cost_history = []

    
    for epoch in range(epochs):
        running_loss = 0.0
        local_model = copy.deepcopy(model.state_dict())

        for i, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            
            if (i + 1) % K == 0:
                with torch.no_grad():
                    global_state_dict = model.state_dict()
                    for key in global_state_dict:
                        global_state_dict[key] = (global_state_dict[key] + local_model[key]) / 2
                    model.load_state_dict(global_state_dict)
                local_model = copy.deepcopy(model.state_dict())
        
        avg_loss = running_loss / len(trainloader)
        loss_history.append(avg_loss)
        accuracy_history.append(evaluate_model(model, testloader))
        communication_cost = measure_communication_cost(model)
        communication_cost_history.append(communication_cost)
        print("Epoch %d: Loss = %.4f, Accuracy = %.2f%%, Communication Cost: %.4f MB" % (epoch + 1, avg_loss, accuracy_history[-1], communication_cost))
    
    return model, loss_history, accuracy_history, communication_cost_history

# %%
def train_hybrid(model, K=5, epochs=10, compression_factor=0.125):
    model = copy.deepcopy(model).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_history = []
    accuracy_history = []
    communication_cost_history = []

    for epoch in range(epochs):
        running_loss = 0.0
        local_model = copy.deepcopy(model.state_dict())

        for i, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            apply_agc_quantization(model)
            optimizer.step()
            running_loss += loss.item()

            if (i + 1) % K == 0:
                with torch.no_grad():
                    global_state_dict = model.state_dict()
                    for key in global_state_dict:
                        global_state_dict[key] = (global_state_dict[key] + local_model[key]) / 2
                    model.load_state_dict(global_state_dict)
                local_model = copy.deepcopy(model.state_dict())

        avg_loss = running_loss / len(trainloader)
        loss_history.append(avg_loss)
        accuracy_history.append(evaluate_model(model, testloader))
        communication_cost = measure_communication_cost(model, compression_factor=compression_factor)
        communication_cost_history.append(communication_cost)

        print("Epoch %d: Loss = %.4f, Accuracy = %.2f%%, Communication Cost: %.4f MB" %
              (epoch + 1, avg_loss, accuracy_history[-1], communication_cost))

    return model, loss_history, accuracy_history, communication_cost_history

# %% [markdown]
# # Train Model

# %%
print("Training Baseline Model")
baseline_model, baseline_loss, baseline_acc, baseline_cost = train_baseline(resnet18(), epochs=50)
baseline_efficiency = compute_communication_efficiency(baseline_acc[-1], len(trainloader))
# Out:
# Training Baseline Model
# Epoch 1: Loss = 1.1804, Accuracy = 68.54%, Communication Cost: 42.6253 MB
# Epoch 2: Loss = 1.4996, Accuracy = 63.57%, Communication Cost: 42.6253 MB
# Epoch 3: Loss = 0.7963, Accuracy = 71.41%, Communication Cost: 42.6253 MB
# Epoch 4: Loss = 0.5761, Accuracy = 76.90%, Communication Cost: 42.6253 MB
# Epoch 5: Loss = 0.4464, Accuracy = 80.10%, Communication Cost: 42.6253 MB
# Epoch 6: Loss = 0.3213, Accuracy = 81.85%, Communication Cost: 42.6253 MB
# Epoch 7: Loss = 0.2184, Accuracy = 82.02%, Communication Cost: 42.6253 MB
# Epoch 8: Loss = 0.1539, Accuracy = 82.48%, Communication Cost: 42.6253 MB
# Epoch 9: Loss = 0.1065, Accuracy = 81.10%, Communication Cost: 42.6253 MB
# Epoch 10: Loss = 0.0835, Accuracy = 82.20%, Communication Cost: 42.6253 MB
# Epoch 11: Loss = 0.0733, Accuracy = 81.72%, Communication Cost: 42.6253 MB
# Epoch 12: Loss = 0.0615, Accuracy = 82.94%, Communication Cost: 42.6253 MB
# Epoch 13: Loss = 0.0574, Accuracy = 83.05%, Communication Cost: 42.6253 MB
# Epoch 14: Loss = 0.0534, Accuracy = 82.92%, Communication Cost: 42.6253 MB
# Epoch 15: Loss = 0.0496, Accuracy = 81.90%, Communication Cost: 42.6253 MB
# Epoch 16: Loss = 0.0453, Accuracy = 81.42%, Communication Cost: 42.6253 MB
# Epoch 17: Loss = 0.0410, Accuracy = 83.22%, Communication Cost: 42.6253 MB
# Epoch 18: Loss = 0.0442, Accuracy = 82.36%, Communication Cost: 42.6253 MB
# Epoch 19: Loss = 0.0366, Accuracy = 82.19%, Communication Cost: 42.6253 MB
# Epoch 20: Loss = 0.0334, Accuracy = 83.35%, Communication Cost: 42.6253 MB
# Epoch 21: Loss = 0.0333, Accuracy = 83.10%, Communication Cost: 42.6253 MB
# Epoch 22: Loss = 0.0335, Accuracy = 82.35%, Communication Cost: 42.6253 MB
# Epoch 23: Loss = 0.0360, Accuracy = 82.52%, Communication Cost: 42.6253 MB
# Epoch 24: Loss = 0.0301, Accuracy = 81.95%, Communication Cost: 42.6253 MB
# Epoch 25: Loss = 0.0287, Accuracy = 81.53%, Communication Cost: 42.6253 MB
# Epoch 26: Loss = 0.0323, Accuracy = 82.43%, Communication Cost: 42.6253 MB
# Epoch 27: Loss = 0.0268, Accuracy = 81.70%, Communication Cost: 42.6253 MB
# Epoch 28: Loss = 0.0284, Accuracy = 82.57%, Communication Cost: 42.6253 MB
# Epoch 29: Loss = 0.0268, Accuracy = 82.67%, Communication Cost: 42.6253 MB
# Epoch 30: Loss = 0.0292, Accuracy = 82.17%, Communication Cost: 42.6253 MB
# Epoch 31: Loss = 0.0231, Accuracy = 83.41%, Communication Cost: 42.6253 MB
# Epoch 32: Loss = 0.0270, Accuracy = 82.93%, Communication Cost: 42.6253 MB
# Epoch 33: Loss = 0.0226, Accuracy = 82.75%, Communication Cost: 42.6253 MB
# Epoch 34: Loss = 0.0252, Accuracy = 82.71%, Communication Cost: 42.6253 MB
# Epoch 35: Loss = 0.0265, Accuracy = 81.71%, Communication Cost: 42.6253 MB
# Epoch 36: Loss = 0.0224, Accuracy = 82.42%, Communication Cost: 42.6253 MB
# Epoch 37: Loss = 0.0211, Accuracy = 79.48%, Communication Cost: 42.6253 MB
# Epoch 38: Loss = 0.0172, Accuracy = 82.50%, Communication Cost: 42.6253 MB
# Epoch 39: Loss = 0.0228, Accuracy = 82.22%, Communication Cost: 42.6253 MB
# Epoch 40: Loss = 0.0187, Accuracy = 80.71%, Communication Cost: 42.6253 MB
# Epoch 41: Loss = 0.0225, Accuracy = 81.70%, Communication Cost: 42.6253 MB
# Epoch 42: Loss = 0.0162, Accuracy = 82.60%, Communication Cost: 42.6253 MB
# Epoch 43: Loss = 0.0229, Accuracy = 82.13%, Communication Cost: 42.6253 MB
# Epoch 44: Loss = 0.0187, Accuracy = 82.32%, Communication Cost: 42.6253 MB
# Epoch 45: Loss = 0.0152, Accuracy = 83.25%, Communication Cost: 42.6253 MB
# Epoch 46: Loss = 0.0194, Accuracy = 82.87%, Communication Cost: 42.6253 MB
# Epoch 47: Loss = 0.0152, Accuracy = 82.01%, Communication Cost: 42.6253 MB
# Epoch 48: Loss = 0.0227, Accuracy = 82.16%, Communication Cost: 42.6253 MB
# Epoch 49: Loss = 0.0197, Accuracy = 81.42%, Communication Cost: 42.6253 MB
# Epoch 50: Loss = 0.0119, Accuracy = 83.09%, Communication Cost: 42.6253 MB

# %%
print("Training Model with AGC")
agc_model, agc_loss, agc_acc, agc_cost = train_with_agc(resnet18(), epochs=50)
agc_efficiency = compute_communication_efficiency(agc_acc[-1], len(trainloader))
# Out:
# Training Model with AGC
# Epoch 1: Loss = 1.1889, Accuracy = 67.90%, Communication Cost: 5.3282 MB
# Epoch 2: Loss = 1.7628, Accuracy = 55.08%, Communication Cost: 5.3282 MB
# Epoch 3: Loss = 1.0592, Accuracy = 67.18%, Communication Cost: 5.3282 MB
# Epoch 4: Loss = 0.7823, Accuracy = 72.58%, Communication Cost: 5.3282 MB
# Epoch 5: Loss = 0.5980, Accuracy = 78.17%, Communication Cost: 5.3282 MB
# Epoch 6: Loss = 0.4470, Accuracy = 79.89%, Communication Cost: 5.3282 MB
# Epoch 7: Loss = 0.3186, Accuracy = 80.25%, Communication Cost: 5.3282 MB
# Epoch 8: Loss = 0.2013, Accuracy = 79.13%, Communication Cost: 5.3282 MB
# Epoch 9: Loss = 0.1378, Accuracy = 79.61%, Communication Cost: 5.3282 MB
# Epoch 10: Loss = 0.0973, Accuracy = 79.73%, Communication Cost: 5.3282 MB
# Epoch 43: Loss = 0.0247, Accuracy = 80.56%, Communication Cost: 5.3282 MB
# Epoch 44: Loss = 0.0227, Accuracy = 79.47%, Communication Cost: 5.3282 MB
# Epoch 45: Loss = 0.0210, Accuracy = 81.08%, Communication Cost: 5.3282 MB
# Epoch 46: Loss = 0.0188, Accuracy = 80.63%, Communication Cost: 5.3282 MB
# Epoch 47: Loss = 0.0205, Accuracy = 78.51%, Communication Cost: 5.3282 MB
# Epoch 48: Loss = 0.0180, Accuracy = 79.38%, Communication Cost: 5.3282 MB
# Epoch 49: Loss = 0.0183, Accuracy = 79.29%, Communication Cost: 5.3282 MB
# Epoch 50: Loss = 0.0173, Accuracy = 78.99%, Communication Cost: 5.3282 MB

# %%
print("Training Model with LU-SGD")
lusgd_model, lusgd_loss, lusgd_acc, lusgd_cost = train_with_lusgd(resnet18(), epochs=50)
lusgd_efficiency = compute_communication_efficiency(lusgd_acc[-1], len(trainloader) // 5)  # LU-SGD syncs every K=5 steps
# Out:
# Training Model with LU-SGD
# Epoch 1: Loss = 1.1297, Accuracy = 62.95%, Communication Cost: 42.6253 MB
# Epoch 2: Loss = 1.7421, Accuracy = 52.99%, Communication Cost: 42.6253 MB
# Epoch 3: Loss = 1.0364, Accuracy = 66.29%, Communication Cost: 42.6253 MB
# Epoch 4: Loss = 0.7487, Accuracy = 72.85%, Communication Cost: 42.6253 MB
# Epoch 5: Loss = 0.5824, Accuracy = 79.17%, Communication Cost: 42.6253 MB
# Epoch 6: Loss = 0.4378, Accuracy = 77.77%, Communication Cost: 42.6253 MB
# Epoch 7: Loss = 0.3174, Accuracy = 78.18%, Communication Cost: 42.6253 MB
# Epoch 8: Loss = 0.2129, Accuracy = 80.06%, Communication Cost: 42.6253 MB
# Epoch 9: Loss = 0.1338, Accuracy = 80.55%, Communication Cost: 42.6253 MB
# Epoch 10: Loss = 0.0894, Accuracy = 81.18%, Communication Cost: 42.6253 MB
# Epoch 11: Loss = 0.0809, Accuracy = 82.34%, Communication Cost: 42.6253 MB
# Epoch 12: Loss = 0.0597, Accuracy = 81.11%, Communication Cost: 42.6253 MB
# Epoch 13: Loss = 0.0566, Accuracy = 81.18%, Communication Cost: 42.6253 MB
# Epoch 14: Loss = 0.0464, Accuracy = 81.11%, Communication Cost: 42.6253 MB
# Epoch 15: Loss = 0.0507, Accuracy = 80.87%, Communication Cost: 42.6253 MB
# Epoch 16: Loss = 0.0399, Accuracy = 80.73%, Communication Cost: 42.6253 MB
# Epoch 17: Loss = 0.0410, Accuracy = 81.53%, Communication Cost: 42.6253 MB
# Epoch 18: Loss = 0.0397, Accuracy = 81.33%, Communication Cost: 42.6253 MB
# Epoch 19: Loss = 0.0348, Accuracy = 81.70%, Communication Cost: 42.6253 MB
# Epoch 20: Loss = 0.0338, Accuracy = 79.20%, Communication Cost: 42.6253 MB
# Epoch 21: Loss = 0.0337, Accuracy = 80.83%, Communication Cost: 42.6253 MB
# Epoch 22: Loss = 0.0298, Accuracy = 81.83%, Communication Cost: 42.6253 MB
# Epoch 23: Loss = 0.0277, Accuracy = 80.59%, Communication Cost: 42.6253 MB
# Epoch 24: Loss = 0.0304, Accuracy = 80.71%, Communication Cost: 42.6253 MB
# Epoch 25: Loss = 0.0281, Accuracy = 80.70%, Communication Cost: 42.6253 MB
# Epoch 26: Loss = 0.0276, Accuracy = 81.33%, Communication Cost: 42.6253 MB
# Epoch 27: Loss = 0.0259, Accuracy = 81.41%, Communication Cost: 42.6253 MB
# Epoch 28: Loss = 0.0257, Accuracy = 81.41%, Communication Cost: 42.6253 MB
# Epoch 29: Loss = 0.0216, Accuracy = 81.61%, Communication Cost: 42.6253 MB
# Epoch 30: Loss = 0.0238, Accuracy = 81.13%, Communication Cost: 42.6253 MB
# Epoch 31: Loss = 0.0222, Accuracy = 81.48%, Communication Cost: 42.6253 MB
# Epoch 32: Loss = 0.0251, Accuracy = 81.22%, Communication Cost: 42.6253 MB
# Epoch 33: Loss = 0.0214, Accuracy = 81.79%, Communication Cost: 42.6253 MB
# Epoch 34: Loss = 0.0200, Accuracy = 81.36%, Communication Cost: 42.6253 MB
# Epoch 35: Loss = 0.0215, Accuracy = 81.25%, Communication Cost: 42.6253 MB
# Epoch 36: Loss = 0.0199, Accuracy = 81.17%, Communication Cost: 42.6253 MB
# Epoch 37: Loss = 0.0194, Accuracy = 81.38%, Communication Cost: 42.6253 MB
# Epoch 38: Loss = 0.0180, Accuracy = 81.64%, Communication Cost: 42.6253 MB
# Epoch 39: Loss = 0.0229, Accuracy = 80.83%, Communication Cost: 42.6253 MB
# Epoch 40: Loss = 0.0194, Accuracy = 81.99%, Communication Cost: 42.6253 MB
# Epoch 41: Loss = 0.0189, Accuracy = 80.43%, Communication Cost: 42.6253 MB
# Epoch 42: Loss = 0.0192, Accuracy = 81.96%, Communication Cost: 42.6253 MB
# Epoch 43: Loss = 0.0152, Accuracy = 81.51%, Communication Cost: 42.6253 MB
# Epoch 44: Loss = 0.0154, Accuracy = 80.87%, Communication Cost: 42.6253 MB
# Epoch 45: Loss = 0.0175, Accuracy = 81.13%, Communication Cost: 42.6253 MB
# Epoch 46: Loss = 0.0185, Accuracy = 81.41%, Communication Cost: 42.6253 MB
# Epoch 47: Loss = 0.0163, Accuracy = 80.85%, Communication Cost: 42.6253 MB
# Epoch 48: Loss = 0.0160, Accuracy = 81.13%, Communication Cost: 42.6253 MB
# Epoch 49: Loss = 0.0160, Accuracy = 81.29%, Communication Cost: 42.6253 MB
# Epoch 50: Loss = 0.0174, Accuracy = 81.73%, Communication Cost: 42.6253 MB

# %%
print("Training Model with Hybrid AGC + LU-SGD")
hybrid_model, hybrid_loss, hybrid_acc, hybrid_cost = train_hybrid(resnet18(), epochs=50)
hybrid_efficiency = compute_communication_efficiency(hybrid_acc[-1], len(trainloader) // 5)
# Epoch 32: Loss = 0.0195, Accuracy = 81.97%, Communication Cost: 5.3282 MB
# Epoch 33: Loss = 0.0229, Accuracy = 82.46%, Communication Cost: 5.3282 MB
# Epoch 34: Loss = 0.0274, Accuracy = 81.66%, Communication Cost: 5.3282 MB
# Epoch 35: Loss = 0.0232, Accuracy = 81.67%, Communication Cost: 5.3282 MB
# Epoch 36: Loss = 0.0250, Accuracy = 82.03%, Communication Cost: 5.3282 MB
# Epoch 37: Loss = 0.0175, Accuracy = 80.59%, Communication Cost: 5.3282 MB
# Epoch 38: Loss = 0.0246, Accuracy = 82.53%, Communication Cost: 5.3282 MB
# Epoch 39: Loss = 0.0149, Accuracy = 80.03%, Communication Cost: 5.3282 MB
# Epoch 40: Loss = 0.0222, Accuracy = 81.71%, Communication Cost: 5.3282 MB
# Epoch 41: Loss = 0.0180, Accuracy = 82.07%, Communication Cost: 5.3282 MB
# Epoch 42: Loss = 0.0208, Accuracy = 82.42%, Communication Cost: 5.3282 MB
# Epoch 43: Loss = 0.0173, Accuracy = 81.89%, Communication Cost: 5.3282 MB
# Epoch 44: Loss = 0.0159, Accuracy = 81.09%, Communication Cost: 5.3282 MB
# Epoch 45: Loss = 0.0190, Accuracy = 82.61%, Communication Cost: 5.3282 MB
# Epoch 46: Loss = 0.0162, Accuracy = 81.61%, Communication Cost: 5.3282 MB
# Epoch 47: Loss = 0.0241, Accuracy = 81.79%, Communication Cost: 5.3282 MB
# Epoch 48: Loss = 0.0164, Accuracy = 81.96%, Communication Cost: 5.3282 MB
# Epoch 49: Loss = 0.0207, Accuracy = 82.09%, Communication Cost: 5.3282 MB
# Epoch 50: Loss = 0.0154, Accuracy = 81.92%, Communication Cost: 5.3282 MB

# %% [markdown]
# # Result

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(len(baseline_loss)), baseline_loss, label="Baseline", marker='o')
plt.plot(range(len(agc_loss)), agc_loss, label="AGC", marker='s')
plt.plot(range(len(lusgd_loss)), lusgd_loss, label="LU-SGD", marker='^')
plt.plot(range(len(hybrid_loss)), hybrid_loss, label="Hybrid AGC + LU-SGD", marker='x')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Convergence Speed Over Time (Loss vs. Epochs)")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(len(baseline_acc)), baseline_acc, label="Baseline", marker='o')
plt.plot(range(len(agc_acc)), agc_acc, label="AGC", marker='s')
plt.plot(range(len(lusgd_acc)), lusgd_acc, label="LU-SGD", marker='^')
plt.plot(range(len(hybrid_acc)), hybrid_acc, label="Hybrid AGC + LU-SGD", marker='x')
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy Comparison Over Time")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(["Baseline", "AGC", "LU-SGD", "Hybrid"], [baseline_efficiency, agc_efficiency, lusgd_efficiency, hybrid_efficiency])
plt.xlabel("Algorithm")
plt.ylabel("Communication Efficiency")
plt.title("Communication Efficiency Comparison")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(["Baseline", "AGC", "LU-SGD", "Hybrid"], [baseline_cost[0], agc_cost[0], lusgd_cost[0], hybrid_cost[0]])
plt.xlabel("Algorithm")
plt.ylabel("Gradient Size (MB)")
plt.title("Gradient Size Comparison")
plt.grid()
plt.show()
